# %%
#importing the dataset
from sklearn.datasets import load_iris
iris=load_iris()
x=iris.data
y=iris.target

#Training and splitting data
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.5,random_state=1)

# Defining the decision tree algorithm 
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
cf=DecisionTreeClassifier()

#training and testing
cf.fit(x_train,y_train)
y_pred=cf.predict(x_test)

print("Predicted class:")
print(y_pred)

#Accuracy
from sklearn import metrics
print("Accuracy: ",metrics.accuracy_score(y_test,y_pred))
#plotting decision tree
import matplotlib.pyplot as plt
plt.figure(figsize=(15,15))
tree.plot_tree(cf,fontsize=10,filled=True,rounded=True,class_names=iris.target_names,feature_names=iris.feature_names)
plt.show()
# Out:
# Predicted class:
# [0 1 1 0 2 1 2 0 0 2 1 0 2 1 1 0 1 1 0 0 1 1 1 0 2 1 0 0 1 1 1 2 1 2 2 0 1
#  0 1 2 2 0 1 2 1 2 0 0 0 1 0 0 2 2 2 2 1 1 2 1 0 2 1 0 0 2 0 1 2 1 1 2 1 0
#  1]
# Accuracy:  0.92
